# %% [markdown]
# ## Import Dependencies

# %%
import numpy as np
from Scripts import VoxelizeData as vd

# %% [markdown]
# ## Voxelize Necessary Datasets

# %% [markdown]
# ### Voxelize ModelNet40 Dataset

# %%
path = 'Data/ModelNet40/'
dataset = 'ModelNet40'
save_path = 'Data/ModelNet40/ModelNet40'

vox = vd.Voxelize(path, dataset, system='Unix', save=True, save_path=save_path, overwrite=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 dataset = 'ModelNet40'
#       3 save_path = 'Data/ModelNet40/ModelNet40'
# ----> 5 vox = vd.Voxelize(path, dataset, system='Unix', save=True, save_path=save_path, overwrite=False)
#
# NameError: name 'vd' is not defined

# %% [markdown]
# ### Test Voxelized ModelNet40 Data

# %%
data = np.load('Data/ModelNet40/ModelNet40Train.npz', allow_pickle=True)

train_data = data['data']
train_labels = data['labels']

print(train_data.shape)
print(train_labels.shape)

#vd.render_voxel_grid(train_data[0])

data = np.load('Data/ModelNet40/ModelNet40Test.npz', allow_pickle=True)

test_data = data['data']
test_labels = data['labels']

plants = []
flower_pots = []

for i in range(0, len(test_data)):
    if test_labels[i] == 'plant':
        plants.append(i)
    if test_labels[i] == 'flower':
        flower_pots.append(i)

print(test_data.shape)
print(test_labels.shape)

for i in range(0, 11):
    vd.render_voxel_grid(test_data[plants[i]])

print('flower pots')

for i in range(0, 11):
    vd.render_voxel_grid(test_data[flower_pots[i]])

vd.render_voxel_grid(test_data[0])
# Out:
# (9843, 32, 32, 32)
# (9843,)
# (2468, 32, 32, 32)
# (2468,)
# flower pots
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 34
#      31 print('flower pots')
#      33 for i in range(0, 11):
# ---> 34     vd.render_voxel_grid(test_data[flower_pots[i]])
#      36 vd.render_voxel_grid(test_data[0])
#
# IndexError: list index out of range

# %% [markdown]
# ### Voxelize Toy4K Dataset

# %%
path = 'Data/toys4k/'
dataset = 'Toys4K'
save_path = 'Data/toys4k/'

vox = vd.Voxelize(path, dataset, system='Unix', save=True, save_path=save_path, overwrite=False)

# %% [markdown]
# ### Test Voxelized Toy4K Data

# %%
data = np.load('Data/toys4k/Toys4KTrain.npz', allow_pickle=True)

train_data = data['data']
train_labels = data['labels']

print(train_data.shape)
print(train_labels.shape)

vd.render_voxel_grid(train_data[0])

data = np.load('Data/toys4k/Toys4KTest.npz', allow_pickle=True)

test_data = data['data']
test_labels = data['labels']

print(test_data.shape)
print(test_labels.shape)

vd.render_voxel_grid(test_data[0])

# %% [markdown]
# ### Voxelize ShapeNet Dataset

# %%
path = 'Data/ShapeNet/'
dataset = 'ShapeNet'
save_path = 'Data/ShapeNet/'

vox = vd.Voxelize(path, dataset, system='Unix', save=True, save_path=save_path, overwrite=False)

# %% [markdown]
# ### Test Voxelized ShapeNet Data

# %%
data = np.load('Data/ShapeNet/ShapeNetTrain.npz', allow_pickle=True)

train_data = data['data']
train_labels = data['labels']

print(train_data.shape)
print(train_labels.shape)

vd.render_voxel_grid(train_data[0])

data = np.load('Data/ShapeNet/ShapeNetTest.npz', allow_pickle=True)

test_data = data['data']
test_labels = data['labels']

print(test_data.shape)
print(test_labels.shape)

vd.render_voxel_grid(test_data[0])
